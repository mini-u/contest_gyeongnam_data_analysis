# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt

# %%
#데이터로드

거제22df = pd.read_csv('20250521151002_AI 관광 분석_거제관광소비.csv', encoding='utf-8')
거창22df = pd.read_csv('20250521151037_AI 관광 분석_거창관광소비.csv', encoding='utf-8')
고성22df = pd.read_csv('./2022년도 경상남도 시군별 소비금액/20250521151106_AI 관광 분석_고성관광소비.csv', encoding='utf-8')
김해22df = pd.read_csv('./2022년도 경상남도 시군별 소비금액/20250521151230_AI 관광 분석_김해관광소비.csv', encoding='utf-8')
남해22df = pd.read_csv('./2022년도 경상남도 시군별 소비금액/20250521151316_AI 관광 분석_남해관광소비.csv', encoding='utf-8')
밀양22df = pd.read_csv('./2022년도 경상남도 시군별 소비금액/20250521151350_AI 관광 분석_밀양관광소비.csv', encoding='utf-8')
사천22df = pd.read_csv('./2022년도 경상남도 시군별 소비금액/20250521151441_AI 관광 분석_사천관광소비.csv', encoding='utf-8')
산청22df = pd.read_csv('./2022년도 경상남도 시군별 소비금액/20250521151600_AI 관광 분석_산청관광소비.csv', encoding='utf-8')
양산22df = pd.read_csv('./2022년도 경상남도 시군별 소비금액/20250521151645_AI 관광 분석_양산관광소비.csv', encoding='utf-8')
의령22df = pd.read_csv('./2022년도 경상남도 시군별 소비금액/20250521151854_AI 관광 분석_의령관광소비.csv', encoding='utf-8')
진주22df = pd.read_csv('./2022년도 경상남도 시군별 소비금액/20250521151926_AI 관광 분석_진주관광소비.csv', encoding='utf-8')
창녕22df = pd.read_csv('./2022년도 경상남도 시군별 소비금액/20250521151954_AI 관광 분석_창녕관광소비.csv', encoding='utf-8')
합포구22df = pd.read_csv('./2022년도 경상남도 시군별 소비금액/20250521152024_AI 관광 분석_창원시마산합포구관광소비.csv', encoding='utf-8')
회원구22df = pd.read_csv('./2022년도 경상남도 시군별 소비금액/20250521152145_AI 관광 분석_창원시마산회원구관광소비.csv', encoding='utf-8')
성산22df = pd.read_csv('./2022년도 경상남도 시군별 소비금액/20250521152216_AI 관광 분석_성산관광소비.csv', encoding='utf-8')
의창22df = pd.read_csv('./2022년도 경상남도 시군별 소비금액/20250521152411_AI 관광 분석_의창관광소비.csv', encoding='utf-8')
진해22df = pd.read_csv('./2022년도 경상남도 시군별 소비금액/20250521160149_AI 관광 분석_진해관광소비.csv', encoding='utf-8')
통영22df = pd.read_csv('./2022년도 경상남도 시군별 소비금액/20250521160222_AI 관광 분석_통영관광소비.csv', encoding='utf-8')
하동22df = pd.read_csv('./2022년도 경상남도 시군별 소비금액/20250521160301_AI 관광 분석_하동관광소비.csv', encoding='utf-8')
함안22df = pd.read_csv('./2022년도 경상남도 시군별 소비금액/20250521160334_AI 관광 분석_함안관광소비.csv', encoding='utf-8')
함양22df = pd.read_csv('./2022년도 경상남도 시군별 소비금액/20250521160407_AI 관광 분석_함양관광소비.csv', encoding='utf-8')
합천22df = pd.read_csv('./2022년도 경상남도 시군별 소비금액/20250521160634_AI 관광 분석_합천관광소비.csv', encoding='utf-8')

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import os

st.set_page_config(layout="wide")
st.title("📊 경상남도 시군별 관광 소비금액 현황 (2022)")

# 👉 시군별 파일명과 변수 매핑 (딕셔너리)
file_paths = {
    "거제": '20250521151002_AI 관광 분석_거제관광소비.csv',
    "거창": '20250521151037_AI 관광 분석_거창관광소비.csv',
    "고성": './2022년도 경상남도 시군별 소비금액/20250521151106_AI 관광 분석_고성관광소비.csv',
    "김해": './2022년도 경상남도 시군별 소비금액/20250521151230_AI 관광 분석_김해관광소비.csv',
    "남해": './2022년도 경상남도 시군별 소비금액/20250521151316_AI 관광 분석_남해관광소비.csv',
    "밀양": './2022년도 경상남도 시군별 소비금액/20250521151350_AI 관광 분석_밀양관광소비.csv',
    "사천": './2022년도 경상남도 시군별 소비금액/20250521151441_AI 관광 분석_사천관광소비.csv',
    "산청": './2022년도 경상남도 시군별 소비금액/20250521151600_AI 관광 분석_산청관광소비.csv',
    "양산": './2022년도 경상남도 시군별 소비금액/20250521151645_AI 관광 분석_양산관광소비.csv',
    "의령": './2022년도 경상남도 시군별 소비금액/20250521151854_AI 관광 분석_의령관광소비.csv',
    "진주": './2022년도 경상남도 시군별 소비금액/20250521151926_AI 관광 분석_진주관광소비.csv',
    "창녕": './2022년도 경상남도 시군별 소비금액/20250521151954_AI 관광 분석_창녕관광소비.csv',
    "마산합포구": './2022년도 경상남도 시군별 소비금액/20250521152024_AI 관광 분석_창원시마산합포구관광소비.csv',
    "마산회원구": './2022년도 경상남도 시군별 소비금액/20250521152145_AI 관광 분석_창원시마산회원구관광소비.csv',
    "성산": './2022년도 경상남도 시군별 소비금액/20250521152216_AI 관광 분석_성산관광소비.csv',
    "의창": './2022년도 경상남도 시군별 소비금액/20250521152411_AI 관광 분석_의창관광소비.csv',
    "진해": './2022년도 경상남도 시군별 소비금액/20250521160149_AI 관광 분석_진해관광소비.csv',
    "통영": './2022년도 경상남도 시군별 소비금액/20250521160222_AI 관광 분석_통영관광소비.csv',
    "하동": './2022년도 경상남도 시군별 소비금액/20250521160301_AI 관광 분석_하동관광소비.csv',
    "함안": './2022년도 경상남도 시군별 소비금액/20250521160334_AI 관광 분석_함안관광소비.csv',
    "함양": './2022년도 경상남도 시군별 소비금액/20250521160407_AI 관광 분석_함양관광소비.csv',
    "합천": './2022년도 경상남도 시군별 소비금액/20250521160634_AI 관광 분석_합천관광소비.csv'
}

# 지역 선택
region = st.selectbox("시군 선택", list(file_paths.keys()))

# 데이터 불러오기
file_path = file_paths[region]
try:
    df = pd.read_csv(file_path, encoding='utf-8')
except:
    st.error("파일을 불러오는 데 문제가 발생했습니다.")
    st.stop()

# 월별 소비금액 그래프
st.subheader(f"{region} - 월별 소비금액 (단위: 원)")

# 월 컬럼 자동 탐색
month_cols = [col for col in df.columns if '월' in col or str(col).isdigit()]
if not month_cols:
    st.warning("월별 컬럼이 존재하지 않습니다.")
    st.write(df.head())
else:
    try:
        # 합계 또는 평균으로 시각화 (원하는 방식 선택)
        month_data = df[month_cols].sum()
        fig, ax = plt.subplots(figsize=(10, 5))
        month_data.plot(kind='bar', ax=ax, color='skyblue')
        ax.set_xlabel("월")
        ax.set_ylabel("소비금액 (원)")
        ax.set_title(f"{region} 월별 소비금액")
        st.pyplot(fig)
    except Exception as e:
        st.error(f"그래프 생성 중 오류: {e}")
# Out:
# 2025-05-22 17:08:57.708 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-22 17:08:57.709 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-22 17:08:57.762
# ...
#   command:
#
#     streamlit run C:\Users\user\miniconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-05-22 17:08:57.763 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-22 17:08:57.763 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-22 17:08:57.764 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
